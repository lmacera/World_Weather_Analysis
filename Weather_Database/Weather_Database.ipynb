# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats= np.random.uniform(-90.000,90.000, size=2000)
lngs=np.random.uniform(-90.000,90.000,size=2000)
lats_lngs= zip(lats,lngs)
lats_lngs

# %%
#add the lats and lngs to a list
coordinates=list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities
cities=[]
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique add to the list
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count
len(cities)
# Out:
# 733

# %%
# Import the requests library
import requests
#Import the API Key
from config import weather_api_key

# %%
#Define URL

url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Creat an empty list to hold the weather data
city_data=[]
#print the beginning of the logging 
print("Beginning Data Retrieval   ")
print("---------------------------")
#create counters
record_count=1
set_count=1
# Out:
# Beginning Data Retrieval
# ---------------------------

# %%
#Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50==0 and i>=50):
        set_count+=1
        record_count=1
    #Create endpoint URL with each city
    city_url= url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count+=1
#Run an API request for each of the cities
    try:
    #Parse the JSON and retrieve data
        city_weather= requests.get(city_url).json()
        #parse out the needed data
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity= city_weather["main"]["humidity"]
        city_clouds= city_weather["clouds"]["all"]
        city_wind= city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description":city_description})
                          
        #If an error is experienced, skip the city
    
    except KeyError:
        print("City not found. Skipping...")
        pass
    #Indicate the Data Loading is complete
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Processing Record 1 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 1 | montepuez
# Processing Record 3 of Set 1 | awjilah
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | florida
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | henties bay
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | port blair
# Processing Record 14 of Set 1 | teguldet
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | truro
# Processing Record 20 of Set 1 | faya
# Processing Record 21 of Set 1 | semnan
# Processing Record 22 of Set 1 | kelme
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | benjamin constant
# Processing Record 26 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 1 | dingle
# Processing Record 28 of Set 1 | narsaq
# Processing Record 29 of Set 1 | vacaresti
# Processing Record 30 of Set 1 | klaksvik
# Processing Record 31 of Set 1 | port-gentil
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | tela
# Processing Record 35 of Set 1 | coihaique
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 1 | marsh harbour
# Processing Record 40 of Set 1 | hambantota
# Processing Record 41 of Set 1 | pangnirtung
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | sumbe
# Processing Record 44 of Set 1 | jardim
# Processing Record 45 of Set 1 | husavik
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | tonneins
# Processing Record 50 of Set 1 | kibre mengist
# Processing Record 1 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 2 | emirdag
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | englehart
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | souillac
# Processing Record 9 of Set 2 | sao jose da coroa grande
# Processing Record 10 of Set 2 | verkhniye kigi
# Processing Record 11 of Set 2 | cockburn town
# Processing Record 12 of Set 2 | olafsvik
# Processing Record 13 of Set 2 | bosaso
# Processing Record 14 of Set 2 | bonfim
# Processing Record 15 of Set 2 | vangaindrano
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | caravelas
# Processing Record 19 of Set 2 | karanpura
# Processing Record 20 of Set 2 | pordim
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | aksarka
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | iranshahr
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | paamiut
# Processing Record 31 of Set 2 | sorland
# Processing Record 32 of Set 2 | tazovskiy
# Processing Record 33 of Set 2 | sebrovo
# Processing Record 34 of Set 2 | hammerfest
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | sabha
# Processing Record 37 of Set 2 | viedma
# Processing Record 38 of Set 2 | beloha
# Processing Record 39 of Set 2 | vastervik
# City not found. Skipping...
# Processing Record 40 of Set 2 | lagos
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | nkhata bay
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | volda
# Processing Record 46 of Set 2 | laguna
# Processing Record 47 of Set 2 | malartic
# Processing Record 48 of Set 2 | torbay
# Processing Record 49 of Set 2 | san jose
# Processing Record 50 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | cascais
# Processing Record 3 of Set 3 | strezhevoy
# Processing Record 4 of Set 3 | igrim
# Processing Record 5 of Set 3 | abu dhabi
# Processing Record 6 of Set 3 | mitsamiouli
# Processing Record 7 of Set 3 | qaanaaq
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | araguacu
# Processing Record 10 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 11 of Set 3 | sechura
# Processing Record 12 of Set 3 | zapolyarnyy
# Processing Record 13 of Set 3 | bria
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | buchanan
# Processing Record 16 of Set 3 | surt
# Processing Record 17 of Set 3 | mayumba
# Processing Record 18 of Set 3 | vigia del fuerte
# Processing Record 19 of Set 3 | retz
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | nelipyno
# Processing Record 22 of Set 3 | raduzhnyy
# Processing Record 23 of Set 3 | hamilton
# Processing Record 24 of Set 3 | luhyny
# Processing Record 25 of Set 3 | bogo
# Processing Record 26 of Set 3 | champagnole
# Processing Record 27 of Set 3 | piacabucu
# Processing Record 28 of Set 3 | dehloran
# Processing Record 29 of Set 3 | belturbet
# Processing Record 30 of Set 3 | pontes e lacerda
# Processing Record 31 of Set 3 | tabuk
# Processing Record 32 of Set 3 | arandis
# Processing Record 33 of Set 3 | cayenne
# Processing Record 34 of Set 3 | padang
# Processing Record 35 of Set 3 | kidal
# Processing Record 36 of Set 3 | yozgat
# Processing Record 37 of Set 3 | constitucion
# Processing Record 38 of Set 3 | la asuncion
# Processing Record 39 of Set 3 | dustlik
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | chulym
# Processing Record 42 of Set 3 | amasia
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | bystrice pod hostynem
# Processing Record 45 of Set 3 | turukhansk
# Processing Record 46 of Set 3 | oranjestad
# Processing Record 47 of Set 3 | tarko-sale
# Processing Record 48 of Set 3 | puerto leguizamo
# Processing Record 49 of Set 3 | belmonte
# Processing Record 50 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 4 | jalu
# Processing Record 2 of Set 4 | dilla
# Processing Record 3 of Set 4 | mairana
# Processing Record 4 of Set 4 | beroroha
# Processing Record 5 of Set 4 | saint-francois
# Processing Record 6 of Set 4 | berlevag
# Processing Record 7 of Set 4 | hofn
# Processing Record 8 of Set 4 | comodoro rivadavia
# Processing Record 9 of Set 4 | mehamn
# Processing Record 10 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 4 | sokolo
# Processing Record 12 of Set 4 | tabora
# Processing Record 13 of Set 4 | peno
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | korla
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | agadez
# Processing Record 18 of Set 4 | chapleau
# Processing Record 19 of Set 4 | bonthe
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | jibuti
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | goderich
# Processing Record 24 of Set 4 | carnot
# Processing Record 25 of Set 4 | muros
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | marienburg
# Processing Record 28 of Set 4 | quelimane
# Processing Record 29 of Set 4 | marv dasht
# City not found. Skipping...
# Processing Record 30 of Set 4 | homa bay
# Processing Record 31 of Set 4 | carauari
# Processing Record 32 of Set 4 | bubaque
# Processing Record 33 of Set 4 | orasu nou
# Processing Record 34 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | acarau
# Processing Record 36 of Set 4 | prieska
# Processing Record 37 of Set 4 | ejigbo
# Processing Record 38 of Set 4 | yar-sale
# Processing Record 39 of Set 4 | odweyne
# Processing Record 40 of Set 4 | santa maria
# Processing Record 41 of Set 4 | gidole
# Processing Record 42 of Set 4 | itarema
# Processing Record 43 of Set 4 | rocha
# Processing Record 44 of Set 4 | grindavik
# Processing Record 45 of Set 4 | sikandra
# Processing Record 46 of Set 4 | melnikovo
# Processing Record 47 of Set 4 | matola
# Processing Record 48 of Set 4 | kyzyl-suu
# Processing Record 49 of Set 4 | ler
# Processing Record 50 of Set 4 | oruro
# Processing Record 1 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | sao miguel do araguaia
# Processing Record 4 of Set 5 | havre-saint-pierre
# Processing Record 5 of Set 5 | kisangani
# Processing Record 6 of Set 5 | hadishahr
# Processing Record 7 of Set 5 | kabo
# Processing Record 8 of Set 5 | kudahuvadhoo
# Processing Record 9 of Set 5 | krasnoselkup
# Processing Record 10 of Set 5 | boyarka
# Processing Record 11 of Set 5 | hualmay
# Processing Record 12 of Set 5 | vozhega
# Processing Record 13 of Set 5 | tanda
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | lagunas
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | quatre cocos
# Processing Record 18 of Set 5 | inhambane
# Processing Record 19 of Set 5 | cururupu
# Processing Record 20 of Set 5 | novovasylivka
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | manta
# Processing Record 23 of Set 5 | promissao
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | ladybrand
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | methoni
# Processing Record 28 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 29 of Set 5 | sao joao da barra
# Processing Record 30 of Set 5 | kindu
# Processing Record 31 of Set 5 | brunswick
# Processing Record 32 of Set 5 | bjornevatn
# Processing Record 33 of Set 5 | hazorasp
# Processing Record 34 of Set 5 | sailana
# Processing Record 35 of Set 5 | belyy yar
# Processing Record 36 of Set 5 | kamenka
# Processing Record 37 of Set 5 | amboise
# Processing Record 38 of Set 5 | conceicao do araguaia
# Processing Record 39 of Set 5 | malakal
# Processing Record 40 of Set 5 | potosi
# Processing Record 41 of Set 5 | zyryanskoye
# Processing Record 42 of Set 5 | wattegama
# Processing Record 43 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 5 | oussouye
# Processing Record 45 of Set 5 | necochea
# Processing Record 46 of Set 5 | monrovia
# Processing Record 47 of Set 5 | ponta delgada
# Processing Record 48 of Set 5 | pinheiral
# Processing Record 49 of Set 5 | susehri
# Processing Record 50 of Set 5 | samaipata
# Processing Record 1 of Set 6 | lalsk
# Processing Record 2 of Set 6 | chimbote
# Processing Record 3 of Set 6 | van
# Processing Record 4 of Set 6 | charlestown
# Processing Record 5 of Set 6 | takoradi
# Processing Record 6 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 6 | sambava
# Processing Record 8 of Set 6 | le pradet
# Processing Record 9 of Set 6 | floro
# Processing Record 10 of Set 6 | mahibadhoo
# Processing Record 11 of Set 6 | point pedro
# Processing Record 12 of Set 6 | cervo
# Processing Record 13 of Set 6 | roncesvalles
# Processing Record 14 of Set 6 | gaur
# Processing Record 15 of Set 6 | mosalsk
# Processing Record 16 of Set 6 | raudeberg
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 6 | gat
# Processing Record 20 of Set 6 | selma
# Processing Record 21 of Set 6 | moanda
# Processing Record 22 of Set 6 | senj
# Processing Record 23 of Set 6 | voyinka
# Processing Record 24 of Set 6 | bolpur
# Processing Record 25 of Set 6 | lima
# Processing Record 26 of Set 6 | keetmanshoop
# Processing Record 27 of Set 6 | baft
# Processing Record 28 of Set 6 | dublin
# Processing Record 29 of Set 6 | valparaiso
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 6 | sinnamary
# Processing Record 34 of Set 6 | boden
# Processing Record 35 of Set 6 | bharatpur
# Processing Record 36 of Set 6 | agirish
# Processing Record 37 of Set 6 | aswan
# Processing Record 38 of Set 6 | cidreira
# Processing Record 39 of Set 6 | chicama
# Processing Record 40 of Set 6 | darlowo
# Processing Record 41 of Set 6 | conde
# Processing Record 42 of Set 6 | naenwa
# City not found. Skipping...
# Processing Record 43 of Set 6 | brae
# Processing Record 44 of Set 6 | kauhajoki
# Processing Record 45 of Set 6 | galyugayevskaya
# Processing Record 46 of Set 6 | carahue
# Processing Record 47 of Set 6 | kuopio
# Processing Record 48 of Set 6 | honningsvag
# Processing Record 49 of Set 6 | neuquen
# Processing Record 50 of Set 6 | kalmunai
# Processing Record 1 of Set 7 | rogovskaya
# Processing Record 2 of Set 7 | kulhudhuffushi
# Processing Record 3 of Set 7 | abha
# Processing Record 4 of Set 7 | timra
# Processing Record 5 of Set 7 | qaqortoq
# Processing Record 6 of Set 7 | yambio
# Processing Record 7 of Set 7 | laerdalsoyri
# Processing Record 8 of Set 7 | san carlos de bariloche
# Processing Record 9 of Set 7 | blagoyevo
# Processing Record 10 of Set 7 | buraydah
# Processing Record 11 of Set 7 | santa rosa
# Processing Record 12 of Set 7 | zaysan
# Processing Record 13 of Set 7 | rio gallegos
# Processing Record 14 of Set 7 | vagur
# Processing Record 15 of Set 7 | the valley
# Processing Record 16 of Set 7 | dungarpur
# Processing Record 17 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 7 | maksatikha
# Processing Record 19 of Set 7 | tadpatri
# Processing Record 20 of Set 7 | benicarlo
# Processing Record 21 of Set 7 | barcelos
# Processing Record 22 of Set 7 | clarence town
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | mabaruma
# Processing Record 25 of Set 7 | jos
# Processing Record 26 of Set 7 | camacha
# Processing Record 27 of Set 7 | birjand
# Processing Record 28 of Set 7 | san benito abad
# Processing Record 29 of Set 7 | benguela
# Processing Record 30 of Set 7 | natal
# Processing Record 31 of Set 7 | bud
# Processing Record 32 of Set 7 | isla mujeres
# Processing Record 33 of Set 7 | mezen
# Processing Record 34 of Set 7 | ihosy
# Processing Record 35 of Set 7 | noyabrsk
# Processing Record 36 of Set 7 | morondava
# Processing Record 37 of Set 7 | soltsy
# Processing Record 38 of Set 7 | yendi
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | yamoussoukro
# Processing Record 41 of Set 7 | maragogi
# Processing Record 42 of Set 7 | sao filipe
# Processing Record 43 of Set 7 | ponta do sol
# Processing Record 44 of Set 7 | ballina
# Processing Record 45 of Set 7 | san ignacio
# Processing Record 46 of Set 7 | reshetylivka
# Processing Record 47 of Set 7 | tukrah
# Processing Record 48 of Set 7 | srivardhan
# Processing Record 49 of Set 7 | wlodawa
# Processing Record 50 of Set 7 | cap-aux-meules
# Processing Record 1 of Set 8 | iralaya
# Processing Record 2 of Set 8 | bereda
# Processing Record 3 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 8 | astana
# Processing Record 5 of Set 8 | papagaios
# Processing Record 6 of Set 8 | bolkhov
# Processing Record 7 of Set 8 | kita
# Processing Record 8 of Set 8 | mangrol
# Processing Record 9 of Set 8 | vestmannaeyjar
# Processing Record 10 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 11 of Set 8 | umba
# Processing Record 12 of Set 8 | storsteinnes
# Processing Record 13 of Set 8 | tonstad
# Processing Record 14 of Set 8 | lubumbashi
# Processing Record 15 of Set 8 | tonantins
# Processing Record 16 of Set 8 | palmaner
# Processing Record 17 of Set 8 | bajil
# Processing Record 18 of Set 8 | bengkulu
# Processing Record 19 of Set 8 | adre
# Processing Record 20 of Set 8 | walvis bay
# Processing Record 21 of Set 8 | comarapa
# Processing Record 22 of Set 8 | putnam
# Processing Record 23 of Set 8 | ocean springs
# Processing Record 24 of Set 8 | meredith
# Processing Record 25 of Set 8 | kang
# Processing Record 26 of Set 8 | tanakpur
# Processing Record 27 of Set 8 | kawambwa
# Processing Record 28 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 8 | akonolinga
# Processing Record 30 of Set 8 | harnoli
# Processing Record 31 of Set 8 | tabas
# Processing Record 32 of Set 8 | roald
# Processing Record 33 of Set 8 | mul
# Processing Record 34 of Set 8 | naro moru
# Processing Record 35 of Set 8 | sagarejo
# Processing Record 36 of Set 8 | massillon
# Processing Record 37 of Set 8 | bandundu
# Processing Record 38 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 39 of Set 8 | sikonge
# Processing Record 40 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 8 | zilair
# Processing Record 42 of Set 8 | irbit
# Processing Record 43 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 8 | koygorodok
# Processing Record 45 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 8 | umm lajj
# Processing Record 47 of Set 8 | bandarbeyla
# Processing Record 48 of Set 8 | barranca
# Processing Record 49 of Set 8 | alta floresta
# Processing Record 50 of Set 8 | ilulissat
# Processing Record 1 of Set 9 | casablanca
# Processing Record 2 of Set 9 | kashi
# Processing Record 3 of Set 9 | tazmalt
# Processing Record 4 of Set 9 | gibara
# Processing Record 5 of Set 9 | polgardi
# Processing Record 6 of Set 9 | aryanah
# Processing Record 7 of Set 9 | nantucket
# Processing Record 8 of Set 9 | koutiala
# Processing Record 9 of Set 9 | karatau
# Processing Record 10 of Set 9 | thilogne
# City not found. Skipping...
# Processing Record 11 of Set 9 | vardo
# Processing Record 12 of Set 9 | andenes
# Processing Record 13 of Set 9 | gimbi
# Processing Record 14 of Set 9 | marzuq
# Processing Record 15 of Set 9 | sur
# Processing Record 16 of Set 9 | san rafael
# Processing Record 17 of Set 9 | moose factory
# Processing Record 18 of Set 9 | gasa
# Processing Record 19 of Set 9 | valuyki
# Processing Record 20 of Set 9 | wladyslawowo
# Processing Record 21 of Set 9 | paris
# Processing Record 22 of Set 9 | mbekenyera
# Processing Record 23 of Set 9 | kumluca
# Processing Record 24 of Set 9 | bafoulabe
# Processing Record 25 of Set 9 | nsanje
# Processing Record 26 of Set 9 | saint-pierre
# Processing Record 27 of Set 9 | douentza
# Processing Record 28 of Set 9 | sao felix do xingu
# Processing Record 29 of Set 9 | totness
# Processing Record 30 of Set 9 | ardakan
# Processing Record 31 of Set 9 | pocao de pedras
# Processing Record 32 of Set 9 | katihar
# Processing Record 33 of Set 9 | baillif
# Processing Record 34 of Set 9 | tonj
# Processing Record 35 of Set 9 | chivay
# Processing Record 36 of Set 9 | khurai
# Processing Record 37 of Set 9 | ouro preto do oeste
# Processing Record 38 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 9 | trencin
# Processing Record 40 of Set 9 | nova olimpia
# Processing Record 41 of Set 9 | margate
# Processing Record 42 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 9 | angoche
# Processing Record 44 of Set 9 | choya
# Processing Record 45 of Set 9 | kommunisticheskiy
# Processing Record 46 of Set 9 | axim
# Processing Record 47 of Set 9 | nykoping
# Processing Record 48 of Set 9 | pizarro
# Processing Record 49 of Set 9 | lerwick
# Processing Record 50 of Set 9 | praia
# Processing Record 1 of Set 10 | livingstonia
# Processing Record 2 of Set 10 | bayji
# Processing Record 3 of Set 10 | neumunster
# Processing Record 4 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 5 of Set 10 | keti bandar
# Processing Record 6 of Set 10 | klerksdorp
# Processing Record 7 of Set 10 | asfi
# Processing Record 8 of Set 10 | plettenberg bay
# Processing Record 9 of Set 10 | puerto carreno
# Processing Record 10 of Set 10 | guarapari
# Processing Record 11 of Set 10 | maxixe
# Processing Record 12 of Set 10 | iquique
# Processing Record 13 of Set 10 | san juan
# Processing Record 14 of Set 10 | la tuque
# Processing Record 15 of Set 10 | kavaratti
# Processing Record 16 of Set 10 | chepareria
# Processing Record 17 of Set 10 | dahra
# Processing Record 18 of Set 10 | ust-tsilma
# Processing Record 19 of Set 10 | qeshm
# Processing Record 20 of Set 10 | ambilobe
# Processing Record 21 of Set 10 | burica
# City not found. Skipping...
# Processing Record 22 of Set 10 | maniitsoq
# Processing Record 23 of Set 10 | manacapuru
# Processing Record 24 of Set 10 | kohat
# Processing Record 25 of Set 10 | macas
# Processing Record 26 of Set 10 | esil
# Processing Record 27 of Set 10 | puerto del rosario
# Processing Record 28 of Set 10 | abnub
# Processing Record 29 of Set 10 | hakkari
# Processing Record 30 of Set 10 | encruzilhada
# Processing Record 31 of Set 10 | mogadouro
# Processing Record 32 of Set 10 | beaupre
# Processing Record 33 of Set 10 | kadnikov
# Processing Record 34 of Set 10 | yining
# Processing Record 35 of Set 10 | hadejia
# Processing Record 36 of Set 10 | mayna
# Processing Record 37 of Set 10 | masunga
# Processing Record 38 of Set 10 | la paz
# Processing Record 39 of Set 10 | mimongo
# Processing Record 40 of Set 10 | domat
# Processing Record 41 of Set 10 | kendallville
# Processing Record 42 of Set 10 | linden
# Processing Record 43 of Set 10 | tevriz
# Processing Record 44 of Set 10 | akyab
# Processing Record 45 of Set 10 | doka
# Processing Record 46 of Set 10 | arkhangelsk
# Processing Record 47 of Set 10 | tefe
# Processing Record 48 of Set 10 | resplendor
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | beisfjord
# Processing Record 1 of Set 11 | lucea
# Processing Record 2 of Set 11 | togur
# Processing Record 3 of Set 11 | chandbali
# Processing Record 4 of Set 11 | morki
# Processing Record 5 of Set 11 | skibbereen
# Processing Record 6 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 7 of Set 11 | virginia beach
# Processing Record 8 of Set 11 | manaus
# Processing Record 9 of Set 11 | kot addu
# Processing Record 10 of Set 11 | seydi
# Processing Record 11 of Set 11 | ushtobe
# Processing Record 12 of Set 11 | asyut
# Processing Record 13 of Set 11 | savinka
# Processing Record 14 of Set 11 | caltanissetta
# Processing Record 15 of Set 11 | timbiqui
# Processing Record 16 of Set 11 | eyemouth
# Processing Record 17 of Set 11 | constantine
# Processing Record 18 of Set 11 | sioux lookout
# Processing Record 19 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 11 | dutse
# Processing Record 21 of Set 11 | timizart
# Processing Record 22 of Set 11 | aasiaat
# Processing Record 23 of Set 11 | roros
# Processing Record 24 of Set 11 | eskisehir
# Processing Record 25 of Set 11 | encruzilhada do sul
# Processing Record 26 of Set 11 | bukene
# Processing Record 27 of Set 11 | inverbervie
# Processing Record 28 of Set 11 | chardara
# Processing Record 29 of Set 11 | dudinka
# Processing Record 30 of Set 11 | chapais
# Processing Record 31 of Set 11 | edea
# Processing Record 32 of Set 11 | lubango
# Processing Record 33 of Set 11 | contamana
# Processing Record 34 of Set 11 | puri
# Processing Record 35 of Set 11 | manjacaze
# Processing Record 36 of Set 11 | bafia
# Processing Record 37 of Set 11 | marawi
# Processing Record 38 of Set 11 | derzhavinsk
# Processing Record 39 of Set 11 | privolzhskiy
# Processing Record 40 of Set 11 | boueni
# Processing Record 41 of Set 11 | camargo
# Processing Record 42 of Set 11 | dobric
# Processing Record 43 of Set 11 | groton
# Processing Record 44 of Set 11 | viksoyri
# City not found. Skipping...
# Processing Record 45 of Set 11 | tessalit
# Processing Record 46 of Set 11 | adrar
# Processing Record 47 of Set 11 | saint anthony
# Processing Record 48 of Set 11 | manosque
# Processing Record 49 of Set 11 | damghan
# Processing Record 50 of Set 11 | kodinar
# Processing Record 1 of Set 12 | weligama
# Processing Record 2 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 3 of Set 12 | mana
# Processing Record 4 of Set 12 | bara
# Processing Record 5 of Set 12 | beyneu
# Processing Record 6 of Set 12 | port antonio
# Processing Record 7 of Set 12 | trairi
# Processing Record 8 of Set 12 | cassilandia
# Processing Record 9 of Set 12 | salinas
# Processing Record 10 of Set 12 | kanye
# Processing Record 11 of Set 12 | tikapur
# Processing Record 12 of Set 12 | channahon
# Processing Record 13 of Set 12 | bikaner
# Processing Record 14 of Set 12 | guanica
# Processing Record 15 of Set 12 | korem
# Processing Record 16 of Set 12 | berbera
# Processing Record 17 of Set 12 | praia da vitoria
# Processing Record 18 of Set 12 | volosovo
# Processing Record 19 of Set 12 | bakuriani
# Processing Record 20 of Set 12 | kattivakkam
# Processing Record 21 of Set 12 | saint-georges
# Processing Record 22 of Set 12 | lydenburg
# Processing Record 23 of Set 12 | plouzane
# Processing Record 24 of Set 12 | shelburne
# Processing Record 25 of Set 12 | verkhnyaya inta
# Processing Record 26 of Set 12 | split
# Processing Record 27 of Set 12 | sosnogorsk
# Processing Record 28 of Set 12 | nioro
# Processing Record 29 of Set 12 | zhezkazgan
# Processing Record 30 of Set 12 | atasu
# Processing Record 31 of Set 12 | tobol
# Processing Record 32 of Set 12 | coquimbo
# Processing Record 33 of Set 12 | urubicha
# Processing Record 34 of Set 12 | dubinino
# Processing Record 35 of Set 12 | khakhea
# Processing Record 36 of Set 12 | horadiz
# Processing Record 37 of Set 12 | bilma
# Processing Record 38 of Set 12 | matara
# Processing Record 39 of Set 12 | uryupinsk
# Processing Record 40 of Set 12 | diu
# Processing Record 41 of Set 12 | peniche
# Processing Record 42 of Set 12 | santiago del estero
# Processing Record 43 of Set 12 | lucapa
# Processing Record 44 of Set 12 | bardiyah
# Processing Record 45 of Set 12 | mogadishu
# Processing Record 46 of Set 12 | bosanski brod
# Processing Record 47 of Set 12 | sirvintos
# Processing Record 48 of Set 12 | opoczno
# Processing Record 49 of Set 12 | taltal
# Processing Record 50 of Set 12 | apricena
# Processing Record 1 of Set 13 | havoysund
# Processing Record 2 of Set 13 | sergeyevka
# Processing Record 3 of Set 13 | eyl
# Processing Record 4 of Set 13 | ondangwa
# Processing Record 5 of Set 13 | maputo
# Processing Record 6 of Set 13 | barcelona
# Processing Record 7 of Set 13 | yarada
# Processing Record 8 of Set 13 | sinnar
# Processing Record 9 of Set 13 | madisonville
# Processing Record 10 of Set 13 | schwerin
# Processing Record 11 of Set 13 | atar
# Processing Record 12 of Set 13 | muli
# Processing Record 13 of Set 13 | saldanha
# Processing Record 14 of Set 13 | baglung
# Processing Record 15 of Set 13 | caxito
# Processing Record 16 of Set 13 | inirida
# Processing Record 17 of Set 13 | kalya
# Processing Record 18 of Set 13 | ipixuna
# Processing Record 19 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 13 | freetown
# Processing Record 21 of Set 13 | el carmen
# Processing Record 22 of Set 13 | holly springs
# Processing Record 23 of Set 13 | beira
# Processing Record 24 of Set 13 | novopskov
# Processing Record 25 of Set 13 | ous
# Processing Record 26 of Set 13 | radstadt
# Processing Record 27 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 28 of Set 13 | grand-santi
# Processing Record 29 of Set 13 | malm
# Processing Record 30 of Set 13 | porto novo
# Processing Record 31 of Set 13 | nara
# Processing Record 32 of Set 13 | amapa
# Processing Record 33 of Set 13 | yalta
# Processing Record 34 of Set 13 | puerto suarez
# Processing Record 35 of Set 13 | naron
# Processing Record 36 of Set 13 | ladario
# Processing Record 37 of Set 13 | fowa
# Processing Record 38 of Set 13 | yafran
# Processing Record 39 of Set 13 | nuuk
# Processing Record 40 of Set 13 | carora
# Processing Record 41 of Set 13 | akdepe
# Processing Record 42 of Set 13 | sabla
# Processing Record 43 of Set 13 | mumford
# Processing Record 44 of Set 13 | lowicz
# Processing Record 45 of Set 13 | adamovka
# Processing Record 46 of Set 13 | tabou
# Processing Record 47 of Set 13 | trelew
# Processing Record 48 of Set 13 | bure
# Processing Record 49 of Set 13 | santa cruz cabralia
# Processing Record 50 of Set 13 | arlit
# Processing Record 1 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 14 | los andes
# Processing Record 3 of Set 14 | pergine valsugana
# Processing Record 4 of Set 14 | soyo
# Processing Record 5 of Set 14 | saint pete beach
# Processing Record 6 of Set 14 | manyana
# Processing Record 7 of Set 14 | kuusamo
# Processing Record 8 of Set 14 | beitbridge
# Processing Record 9 of Set 14 | veraval
# Processing Record 10 of Set 14 | barmer
# Processing Record 11 of Set 14 | mainpuri
# Processing Record 12 of Set 14 | deori khas
# Processing Record 13 of Set 14 | paita
# Processing Record 14 of Set 14 | san joaquin
# Processing Record 15 of Set 14 | mizan teferi
# Processing Record 16 of Set 14 | bahua
# Processing Record 17 of Set 14 | harper
# Processing Record 18 of Set 14 | onega
# Processing Record 19 of Set 14 | filadelfia
# Processing Record 20 of Set 14 | gamba
# Processing Record 21 of Set 14 | promyshlennyy
# Processing Record 22 of Set 14 | hellendoorn
# Processing Record 23 of Set 14 | pudozh
# Processing Record 24 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 14 | myski
# Processing Record 26 of Set 14 | kugulta
# Processing Record 27 of Set 14 | huarmey
# Processing Record 28 of Set 14 | carutapera
# Processing Record 29 of Set 14 | gazojak
# Processing Record 30 of Set 14 | sakakah
# Processing Record 31 of Set 14 | afsin
# Processing Record 32 of Set 14 | cadillac
# Processing Record 33 of Set 14 | cravo norte
# Processing Record 34 of Set 14 | kalanwali
# Processing Record 35 of Set 14 | tokonou
# Processing Record 36 of Set 14 | annonay
# Processing Record 37 of Set 14 | pontal do parana
# Processing Record 38 of Set 14 | sabaudia
# Processing Record 39 of Set 14 | leua
# Processing Record 40 of Set 14 | marsa matruh
# Processing Record 41 of Set 14 | lincoln
# Processing Record 42 of Set 14 | marrakesh
# Processing Record 43 of Set 14 | swellendam
# Processing Record 44 of Set 14 | boulsa
# Processing Record 45 of Set 14 | izberbash
# Processing Record 46 of Set 14 | puerto narino
# Processing Record 47 of Set 14 | opuwo
# Processing Record 48 of Set 14 | carlisle
# Processing Record 49 of Set 14 | aden
# Processing Record 50 of Set 14 | jacareacanga
# Processing Record 1 of Set 15 | minas
# Processing Record 2 of Set 15 | balad
# Processing Record 3 of Set 15 | gurupi
# Processing Record 4 of Set 15 | swidwin
# Processing Record 5 of Set 15 | cefalu
# Processing Record 6 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 7 of Set 15 | corinto
# Processing Record 8 of Set 15 | palenque
# Processing Record 9 of Set 15 | mayor pablo lagerenza
# Processing Record 10 of Set 15 | chama
# Processing Record 11 of Set 15 | wukari
# Processing Record 12 of Set 15 | koundara
# Processing Record 13 of Set 15 | aquiraz
# Processing Record 14 of Set 15 | najran
# Processing Record 15 of Set 15 | novyye burasy
# Processing Record 16 of Set 15 | rosetta
# Processing Record 17 of Set 15 | gogrial
# Processing Record 18 of Set 15 | aracatuba
# Processing Record 19 of Set 15 | razole
# Processing Record 20 of Set 15 | seminole
# Processing Record 21 of Set 15 | valverde del camino
# Processing Record 22 of Set 15 | aiken
# Processing Record 23 of Set 15 | rockland
# Processing Record 24 of Set 15 | bugulma
# Processing Record 25 of Set 15 | goffstown
# Processing Record 26 of Set 15 | leh
# Processing Record 27 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 28 of Set 15 | caninde
# Processing Record 29 of Set 15 | santa fe
# Processing Record 30 of Set 15 | vihti
# Processing Record 31 of Set 15 | guliston
# Processing Record 32 of Set 15 | netarhat
# Processing Record 33 of Set 15 | istisu
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
len(city_data)
# Out:
# 684

# %%
#Convert the city_data dictionary to a datafram
city_data_df=pd.DataFrame(city_data)
city_data_df.tail(10)
# Out:
#           City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 674   Rockland  41.1668 -74.0496     58.91        64          83        5.12
# 675    Bugulma  54.5500  52.8000     43.66        73          76        9.06
# 676  Goffstown  43.0204 -71.6003     59.20        54          40        5.01
# 677        Leh  34.1667  77.5833     31.62        88         100        3.89
# 678    Caninde  -4.3589 -39.3117     90.81        43          98        3.91
# 679   Santa Fe -31.6333 -60.7000     74.91        53          97       10.00
# 680      Vihti  60.4170  24.3197     34.79        90         100        8.01
# 681   Guliston  40.4897  68.7842     48.02        31           2        3.44
# 682   Netarhat  23.4833  84.2667     57.60        75           0        2.84
# 683     Istisu  40.9457  48.0738     43.47        66           0        2.44
#
#     Country Current Description
# 674      US       broken clouds
# 675      RU       broken clouds
# 676      US    scattered clouds
# 677      IN          light snow
# 678      BR     overcast clouds
# 679      AR     overcast clouds
# 680      FI     overcast clouds
# 681      UZ           clear sky
# 682      IN           clear sky
# 683      AZ           clear sky

# %%
# Chnage column order
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Montepuez      MZ -13.1256   38.9997     76.39        51          28
# 1      Awjilah      LY  29.1081   21.2869     77.65        29           3
# 2    Busselton      AU -33.6500  115.3333     53.10        82          30
# 3   Georgetown      MY   5.4112  100.3354     80.53        89          40
# 4  Port Alfred      ZA -33.5906   26.8910     61.20        70          27
# 5      Florida      US  28.7505  -82.5001     88.92        62           1
# 6     Hermanus      ZA -34.4187   19.2345     57.90        70          62
# 7  Henties Bay      NA -22.1160   14.2845     62.85        83           0
# 8   Bredasdorp      ZA -34.5322   20.0403     58.32        72          68
# 9   Port Blair      IN  11.6667   92.7500     80.42        78          90
#
#    Wind Speed Current Description
# 0       10.42    scattered clouds
# 1        9.01           clear sky
# 2        6.26    scattered clouds
# 3        7.00    scattered clouds
# 4       29.28    scattered clouds
# 5        5.75           clear sky
# 6        8.14       broken clouds
# 7       15.39           clear sky
# 8       10.36       broken clouds
# 9        1.83     overcast clouds

# %%
#Create the output file(CSV)
output_data_file= "cities.csv"
#export the city_data into a CSV"
city_data_df.to_csv(output_data_file, index_label="City_ID")
